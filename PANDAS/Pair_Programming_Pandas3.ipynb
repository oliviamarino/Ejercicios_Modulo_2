# %%
from pydataset import data
import pandas as pd

# %% [markdown]
# EJERCICIO 1: Cargar el dataset
# 💡 Pista Si hacemos la carga del dataset sin el parámetro encoding nos dará error. Aquí tenéis una lista de los encodings disponibles en pandas. Buscad por los encoding de tipo ISO.

# %%
df_csv = pd.read_csv("attacks.csv")
df_csv.head()
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                                                      href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#                                                                              href  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#   Case Number.1 Case Number.2 original order Unnamed: 22  Unnamed: 23
# 0    2018.06.25    2018.06.25         6303.0         NaN          NaN
# 1    2018.06.18    2018.06.18         6302.0         NaN          NaN
# 2    2018.06.09    2018.06.09         6301.0         NaN          NaN
# 3    2018.06.08    2018.06.08         6300.0         NaN          NaN
# 4    2018.06.04    2018.06.04         6299.0         NaN          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# EJERCICIO 2: Haced una exploración básica del DataFrame:
#
# Ej 2.1: ¿Cuántas filas y columnas tiene el DataFrame?

# %%
print('El número de filas y columnas del dataframe es:', df_csv.shape)
# Out:
# El número de filas y columnas del dataframe es: (6114, 22)

# %% [markdown]
# Ej 2.2: Mostrad las primeras cinco filas y las últimas cinco filas del DataFrame.

# %%
print('Las primeras 5 filas del df son:', '\n')
df_csv.head()
# Out:
# Las primeras 5 filas del df son:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                                                      href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#                                                                              href  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#   Case Number.1 Case Number.2 original order Unnamed: 22  Unnamed: 23
# 0    2018.06.25    2018.06.25         6303.0         NaN          NaN
# 1    2018.06.18    2018.06.18         6302.0         NaN          NaN
# 2    2018.06.09    2018.06.09         6301.0         NaN          NaN
# 3    2018.06.08    2018.06.08         6300.0         NaN          NaN
# 4    2018.06.04    2018.06.04         6299.0         NaN          NaN
#
# [5 rows x 22 columns]

# %%
print('Las últimas 5 filas del dataframe son:', '\n')
df_csv.tail()
# Out:
# Las últimas 5 filas del dataframe son:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 6109    New South Wales    Georges Head, off Port Jackson
# 6110     South Carolina                    Off Charleston
# 6111  Western Australia  Hamelin Harbour, at Faure Island
# 6112                NaN                               NaN
# 6113                NaN                               NaN
#
#                              Activity                             Name Sex   \
# 6109                              NaN                             boat  NaN
# 6110                              NaN                    Captain Jones    M
# 6111                              NaN  M. Lefevre & a sailor (rescuer)    M
# 6112                              NaN                              NaN  NaN
# 6113  Standing on landed shark's tail                 Stephen Pettigew    N
#
#       ...   Species   \
# 6109  ...        NaN
# 6110  ...        NaN
# 6111  ...        NaN
# 6112  ...        NaN
# 6113  ...  12' shark
#
#                                           Investigator or Source  \
# 6109                                  Sydney Gazette, 2/26/1804
# 6110                                     Evening Post, 6/13/1803
# 6111  F.  Peron ref in G.P. Whitley (Fishes of Australia), p.13
# 6112                           Evening Post (New York) 4/13/1802
# 6113                                The Evening Post, 12/18/1801
#
#                                   pdf  \
# 6109  1804.02.26-boat-GeorgesHead.pdf
# 6110             1803.05.17-Jones.pdf
# 6111           1803.03.00-Lefevre.pdf
# 6112           1802.04.13.R-India.pdf
# 6113       1801.12.18.R-Pettigrew.pdf
#
#                                                                                href formula  \
# 6109  http://sharkattackfile.net/spreadsheets/pdf_directory/1804.02.26-boat-GeorgesHead.pdf
# 6110             http://sharkattackfile.net/spreadsheets/pdf_directory/1803.05.17-Jones.pdf
# 6111           http://sharkattackfile.net/spreadsheets/pdf_directory/1803.03.00-Lefevre.pdf
# 6112           http://sharkattackfile.net/spreadsheets/pdf_directory/1802.04.13.R-India.pdf
# 6113       http://sharkattackfile.net/spreadsheets/pdf_directory/1801.12.18.R-Pettigrew.pdf
#
#                                                                                        href  \
# 6109  http://sharkattackfile.net/spreadsheets/pdf_directory/1804.02.26-boat-GeorgesHead.pdf
# 6110             http://sharkattackfile.net/spreadsheets/pdf_directory/1803.05.17-Jones.pdf
# 6111           http://sharkattackfile.net/spreadsheets/pdf_directory/1803.03.00-Lefevre.pdf
# 6112           http://sharkattackfile.net/spreadsheets/pdf_directory/1802.04.13.R-India.pdf
# 6113       http://sharkattackfile.net/spreadsheets/pdf_directory/1801.12.18.R-Pettigrew.pdf
#
#      Case Number.1 Case Number.2 original order Unnamed: 22  Unnamed: 23
# 6109  1804.02.26.R  1804.02.26.R          176.0         NaN          NaN
# 6110    1803.05.17    1803.05.17          175.0         NaN          NaN
# 6111    1803.03.00    1803.03.00          174.0         NaN          NaN
# 6112  1802.04.13.R  1802.04.13.R          173.0         NaN          NaN
# 6113  1801.12.18.R  1801.12.18.R          172.0         NaN          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# Ej 2.3: Mostrad 2 filas al azar del DataFrame.

# %%
print('Dos filas al azar del df:')
df_csv.sample(2)
# Out:
# Dos filas al azar del df:
#       Unnamed: 0 Case Number    Year        Type        Country  \
# 283          284  2016.04.19  2016.0  Unprovoked      AUSTRALIA
# 2498        2505  1993.03.00  1993.0  Unprovoked  NEW CALEDONIA
#
#                  Area                    Location  Activity              Name  \
# 283   New South Wales  First Sun Beach, Byron Bay  Swimming         Zak Kedem
# 2498   South Province                Île de Casey  Swimming  Frederic Dolbeau
#
#      Sex   ...         Species           Investigator or Source  \
# 283     M  ...  Wobbegong shark  Gold Coast Bulletin, 4/19/2016
# 2498  NaN  ...              NaN                      W. Leander
#
#                          pdf  \
# 283     2016.04.19-Kedem.pdf
# 2498  1993.03.00-Dolbeau.pdf
#
#                                                                       href formula  \
# 283     http://sharkattackfile.net/spreadsheets/pdf_directory/2016.04.19-Kedem.pdf
# 2498  http://sharkattackfile.net/spreadsheets/pdf_directory/1993.03.00-Dolbeau.pdf
#
#                                                                               href  \
# 283     http://sharkattackfile.net/spreadsheets/pdf_directory/2016.04.19-Kedem.pdf
# 2498  http://sharkattackfile.net/spreadsheets/pdf_directory/1993.03.00-Dolbeau.pdf
#
#      Case Number.1 Case Number.2 original order Unnamed: 22  Unnamed: 23
# 283     2016.04.19    2016.04.19         6019.0         NaN          NaN
# 2498    1993.03.00    1993.03.00         3798.0         NaN          NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# Ej 2.4: ¿Cuál es el nombre de las columnas del DataFrame?

# %%
print('El nombre de las columnas del df:','\n', df_csv.columns)
# Out:
# El nombre de las columnas del df:
#  Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# Ej 2.5: ¿Cuáles son los principales estádisticos del DataFrame? Mostrad por separado las variables categóricas y las variables numéricas.

# %%
print('Los principales estadísticos de las variables categóricas son:')
df_csv.describe(include = 'object')
# Out:
# Los principales estadísticos de las variables categóricas son:
#        Case Number        Type Country     Area  \
# count         6113        6110    6074     5706
# unique        6113           8     201      791
# top     2018.06.25  Unprovoked     USA  Florida
# freq             1        4438    2200     1025
#
#                                 Location Activity  Name  Sex    Age  \
# count                               5626     5603  5914  5564  3448
# unique                              4020     1484  5118     6   156
# top     New Smyrna Beach, Volusia County  Surfing  male     M    17
# freq                                 162      966   511  4939   154
#
#              Time     Species  Investigator or Source                     pdf  \
# count        2934         3409                   6098                    6114
# unique        366         1529                   4837                    6105
# top     Afternoon  White shark         C. Moore, GSAF  1898.00.00.R-Syria.pdf
# freq          183          161                     95                       2
#
#                                                                         href formula  \
# count                                                                           6113
# unique                                                                          6104
# top     http://sharkattackfile.net/spreadsheets/pdf_directory/1898.00.00.R-Syria.pdf
# freq                                                                               2
#
#                                                                               href  \
# count                                                                         6114
# unique                                                                        6099
# top     http://sharkattackfile.net/spreadsheets/pdf_directory/w014.01.25-Grant.pdf
# freq                                                                             4
#
#        Case Number.1 Case Number.2   Unnamed: 22 Unnamed: 23
# count           6114          6114             1           2
# unique          6113          6114             1           2
# top       1952.08.04    2018.06.25  stopped here      Teramo
# freq               2             1             1           1

# %% [markdown]
# Ej 2.6: ¿Cuál es el porcentaje de valores nulos en cada columna?

# %%
import numpy as np

nulos = df_csv.isnull().sum()
porcentaje_isnull = (nulos/ len(df_csv)*100)
porcentaje_isnull = np.round(porcentaje_isnull, decimals = 2)
print(porcentaje_isnull)
# Out:
# Unnamed: 0                 0.00
# Case Number                0.02
# Year                       0.00
# Type                       0.07
# Country                    0.65
# Area                       6.67
# Location                   7.98
# Activity                   8.36
# Name                       3.27
# Sex                        9.00
# Age                       43.60
# Time                      52.01
# Species                   44.24
# Investigator or Source     0.26
# pdf                        0.00
# href formula               0.02
# href                       0.00
# Case Number.1              0.00
# Case Number.2              0.00
# original order             0.00
# Unnamed: 22               99.98
# Unnamed: 23               99.97
# dtype: float64

# %% [markdown]
# Ej 2.7: Sacad los valores únicos y su frecuencia de las variables numéricas. Almacenad los resultados en un diccionario. Uno para cada variable.

# %%
columnas = df_csv.columns
frecuencia = df_csv[df_csv.columns].value_counts()

lista_frec = []

for nombre in columnas:
    lista_frec.append(df_csv[str(nombre)].value_counts())

# %%
diccionario_frecuencias = {}

for x in columnas:
    for y in lista_frec:
        diccionario_frecuencias[x]= y
        lista_frec.remove(y)
        break

#print(diccionario_frecuencias) #Esto es UN diccionario con todas las columnas

# %% [markdown]
# Ej 2.8: Cambiad el nombre de las columnas para que todas estén en minúsculas y reemplazad los espacios por _.

# %%
columnas_minuscula = {nombre :  nombre.lower() for nombre in df_csv.columns}
columnas_minuscula
# Out:
# {'Unnamed: 0': 'unnamed: 0',
#  'Case Number': 'case number',
#  'Year': 'year',
#  'Type': 'type',
#  'Country': 'country',
#  'Area': 'area',
#  'Location': 'location',
#  'Activity': 'activity',
#  'Name': 'name',
#  'Sex ': 'sex ',
#  'Age': 'age',
#  'Time': 'time',
#  'Species ': 'species ',
#  'Investigator or Source': 'investigator or source',
#  'pdf': 'pdf',
#  'href formula': 'href formula',
#  'href': 'href',
#  'Case Number.1': 'case number.1',
#  'Case Number.2': 'case number.2',
#  'original order': 'original order',
#  'Unnamed: 22': 'unnamed: 22',
#  'Unnamed: 23': 'unnamed: 23'}

# %% [markdown]
# Ej 2.9: Eliminad las columnas de Unnamed: 22 y Unnamed: 23, Case Number.1, Case Number.2, original order, Investigator or Source, pdf, href formula.

# %%
df_eliminar = df_csv.drop(["Unnamed: 22", "Unnamed: 23", "Case Number.1", "Case Number.2", "original order", "Investigator or Source",
 "pdf", "href formula"], axis = 1)

df_eliminar.head()
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             Time         Species   \
# 0          18h00      White shark
# 1  14h00  -15h00              NaN
# 2          07h45              NaN
# 3            NaN        2 m shark
# 4            NaN  Tiger shark, 3m
#
#                                                                              href
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf

# %% [markdown]
# Ej 2.10: Establece la columna Case Number como índice del DataFrame.

# %%
df_eliminar.set_index(['Case Number'], inplace = True)
df_eliminar.head()
# Out:
#              Unnamed: 0    Year        Type    Country             Area  \
# Case Number
# 2018.06.25            0  2018.0     Boating        USA       California
# 2018.06.18            1  2018.0  Unprovoked        USA          Georgia
# 2018.06.09            2  2018.0     Invalid        USA           Hawaii
# 2018.06.08            3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 2018.06.04            4  2018.0    Provoked     MEXICO           Colima
#
#                                    Location     Activity             Name  \
# Case Number
# 2018.06.25      Oceanside, San Diego County     Paddling      Julie Wolfe
# 2018.06.18   St. Simon Island, Glynn County     Standing  Adyson McNeely
# 2018.06.09                     Habush, Oahu      Surfing      John Denges
# 2018.06.08               Arrawarra Headland      Surfing             male
# 2018.06.04                         La Ticla  Free diving   Gustavo Ramos
#
#             Sex   Age           Time         Species   \
# Case Number
# 2018.06.25     F   57          18h00      White shark
# 2018.06.18     F   11  14h00  -15h00              NaN
# 2018.06.09     M   48          07h45              NaN
# 2018.06.08     M  NaN            NaN        2 m shark
# 2018.06.04     M  NaN            NaN  Tiger shark, 3m
#
#                                                                                        href
# Case Number
# 2018.06.25       http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 2018.06.18     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2018.06.09      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 2018.06.08   http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 2018.06.04       http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf

# %% [markdown]
# EJERCICIO 3: Guarda el csv que no tiene esas columnas para seguir usándolo mañana.

# %%
df_eliminar.to_csv("attacks_modificado.csv")
