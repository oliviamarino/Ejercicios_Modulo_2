# %%
import pandas as pd
import datetime

# %%
attacks = pd.read_csv("attacks_todos.csv", index_col = 0)
attacks.sample(2)
# Out:
#      Case Number    Year        Type           Country             Area  \
# 2038  2000.06.30  2000.0  Unprovoked  PAPUA NEW GUINEA  Madang Province
# 421   2015.05.24  2015.0  Unprovoked               USA          Florida
#
#                                                Location  Activity  \
# 2038  Long Island near Madang, about 500 km (310 mil...       NaN
# 421                        Cocoa Beach, Brevard  County  Swimming
#
#               Name Sex   Age Time Species  Fatal (Y/N)  \
# 2038          male    M  NaN  NaN      NaN           Y
# 421   Alysa Whetro    F   13  NaN      NaN           N
#
#                                                  Injury         Date
# 2038                                              FATAL  30-Jun-2000
# 421   Puncture wounds to lower left leg and ankle, s...  24-May-2015

# %% [markdown]
# ### EJERCICIO 1

# %%
ataques_copia = attacks.copy()

# %%
ataques_copia['Date'] = ataques_copia['Date'].apply(pd.to_datetime)
ataques_copia.head(1)

# %%
def sacar_mes(x):
    return x.split(".")[1]

# %%
attacks["mes"] = (attacks["Case Number"].apply(sacar_mes))

# %% [markdown]
# ### EJERCICIO 2
# Vamos con la columna fatal_(y/n). Lo primero que tenéis que hacer es evaluar los valores únicos que hay. Esperaríamos tener solo dos valores: y y n, pero tristemente no es así 😭. Cread yçuna columna nueva y una función que devuelva unicamente y o n y que devuelva un nulo (NaN) si no se encuentra el valor.

# %% [markdown]
# Lo hemos resuelto de una manera alternativa porque no sabíamos cómo hacerlo con una funcion y apply.

# %%
lista_N_Y_NaN = []  

def sacar_NoY(x):                        #Con esta funcion añadimos a la lista los valores que nos interesan y sustituimos 
    for letra in x:                      #  los que no por NaN.
        if letra == 'N':
            lista_N_Y_NaN.append(letra)
        elif letra == 'Y':
            lista_N_Y_NaN.append(letra)
        else:
            lista_N_Y_NaN.append('NaN')
    print(lista_N_Y_NaN)
sacar_NoY(ataques_copia['Fatal (Y/N)'])

# %%
lista_fatal_nuevos = pd.DataFrame(lista_N_Y_NaN)   #Creamos un dataframe de la lista.
lista_fatal_nuevos
# Out:
#       0
# 0     N
# 1     N
# 2     N
# 3     N
# 4     N
# ...  ..
# 6279  Y
# 6280  Y
# 6281  Y
# 6282  Y
# 6283  Y
#
# [6284 rows x 1 columns]

# %% [markdown]
# Añadimos la columna nueva al df.

# %%
#del ataques_copia["FATAL (Y/N/NaN"]
#df['FATAL (Y/N/NaN)'] = lista__fatal_nuevos
ataques_copia.head()
# Out:
#   Case Number    Year        Type    Country             Area  \
# 0  2018.06.25  2018.0     Boating        USA       California
# 1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             Time         Species  Fatal (Y/N)  \
# 0          18h00      White shark           N
# 1  14h00  -15h00              NaN           N
# ...

# %% [markdown]
# A partir de aquí son pruebas que hemos hecho para intentara resolverlo usando funciones, try/except y apply.

# %%
# fatal_values = ataques_copia['Fatal (Y/N)'].value_counts()
# fatal_values

# %%
# def fatales(x, y):
#     try: 
#         return x,y
#     except: 
#         return 'NaN'

# %%
# ataques_copia["FATAL (N/Y) new"] = ataques_copia.apply(lambda datos: fatales( datos['N'], 
#                                   datos['Y']), axis = 0)

# %%
# def sacar_NoY(x):
#     lista_N_Y_NaN = []
#     try:
#         for letra in x:
#             if letra == 'N':
#                 lista_N_Y_NaN.append(letra)
#             elif letra == 'Y':
#                 lista_N_Y_NaN.append(letra)
            
#     except:
#         lista_N_Y_NaN.append('NaN')
    
#     print(lista_N_Y_NaN)
    
# sacar_NoY(ataques_copia['Fatal (Y/N)'])
